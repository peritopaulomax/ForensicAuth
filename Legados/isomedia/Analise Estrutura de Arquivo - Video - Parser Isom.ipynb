# %%
import sys
import os
sys.path.append(os.getcwd())
from isom_parser_sepael import print_graph_structure
from isom_compare_sepael import compare_structures, print_comparison_results, get_specific_comparison
from isom_similarity_matrix_sepael import create_and_plot_similarity_matrix


# Uso do comparador
standard_dir = "./P"
questioned_dir = "./Q"
similarity_threshold = 0.9  # Ajuste este valor conforme necessário

# %%
exact_matches, partial_matches, standard_structures, questioned_structures, all_comparisons = compare_structures(standard_dir, questioned_dir, similarity_threshold)
print_comparison_results(exact_matches, partial_matches, standard_structures, questioned_structures, False)
# Out:
# Resultados da Comparação:
# -------------------------
#
# Correspondências Exatas:
#   Arquivo Questionado: Brasilia.MOV
#     Corresponde exatamente aos seguintes padrões:
#       - bauer.MOV
#   Arquivo Questionado: IMG_5769.MOV
#     Corresponde exatamente aos seguintes padrões:
#       - Alex.MOV
#   Arquivo Questionado: desconhecido.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - gustavo.mp4
#   Arquivo Questionado: curso.MOV
#     Corresponde exatamente aos seguintes padrões:
#       - bauer.MOV
#   Arquivo Questionado: Quest15-08-25.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - rogerio.mp4
#       - Paulo_Marcelo.mp4
#   Arquivo Questionado: xxyz.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - Garbe.mp4
#   Arquivo Questionado: Carpete.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - Scarpelli.mp4
#       - Hugo.mp4
#   Arquivo Questionado: caneca.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - Bruno Simmer.mp4
#   Arquivo Questionado: Aula2.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - rogerio.mp4
#       - Paulo_Marcelo.mp4
#   Arquivo Questionado: calopsita.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - claudio.mp4
#   Arquivo Questionado: VID_20250815_111418.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - Mauricio.mp4
#       - Ronaldo.mp4
#   Arquivo Questionado: VideoQualquer.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - claudio.mp4
#   Arquivo Questionado: VID_20250815_111420.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - Mauricio.mp4
#       - Ronaldo.mp4
#   Arquivo Questionado: 20250815_113010.mp4
#     Corresponde exatamente aos seguintes padrões:
#       - khyale.mp4
#   Arquivo Questionado: video123124234.mov
#     Corresponde exatamente aos seguintes padrões:
#       - Marcelo.MOV
#       - nureyev.MOV
#
# Correspondências Parciais:
#   Arquivo Questionado: 20250815_112502.mp4
#     Semelhante a: Braid.mp4 (Similaridade: 0.98)
#
# Arquivos Questionados sem Correspondências:
#   - WhatsApp Video 2025-08-15 at 11.19.50.mp4
#
# Padrões não Utilizados:
#   - Felipe.MOV
#   - Reneu.mp4
#
# Resumo:
#   Total de arquivos padrão processados: 19
#   Total de arquivos questionados processados: 17
#   Arquivos questionados com correspondência exata: 15
#   Arquivos questionados com correspondência parcial: 1
#   Arquivos questionados sem correspondências: 1
#   Padrões não utilizados: 2

# %%
graph = questioned_structures['20250815_112502.mp4']
print_graph_structure(graph)
# Out:
# ftyp (Tamanho: 24, Offset: 0)
#   Descrição: File Type Box - Identifica o tipo e as especificações do arquivo
#   size: 24
#   offset: 8
# mdat (Tamanho: 10599668, Offset: 24)
#   Descrição: Media Data Box - Contém os dados de mídia reais (áudio, vídeo)
#   size: 10599668
#   offset: 40
# moov (Tamanho: 4327, Offset: 10599692)
#   Descrição: Movie Box - Contém todos os metadados do filme
#   mvhd (Tamanho: 108, Offset: 10599700)
#     Descrição: Movie Header Box - Metadados gerais do filme
#     version: 0
#     flags: 0
#     creation_time: 3838112710
#     modification_time: 3838112710
#     timescale: 10000
#     duration: 57059
#   udta (Tamanho: 145, Offset: 10599808)
#     Descrição: User Data Box - Informações definidas pelo usuário
#     SDLN (Tamanho: 16, Offset: 10599816)
#       Descrição: Box não documentado
#       size: 16
#       offset: 10599824
#     smrd (Tamanho: 16, Offset: 10599832)
#       Descrição: Box não documentado
#       size: 16
#       offset: 10599840
#     auth (Tamanho: 31, Offset: 10599848)
#       Descrição: Box não documentado
#       size: 31
#       offset: 10599856
#     smta (Tamanho: 42, Offset: 10599879)
#       Descrição: Box não documentado
#       size: 42
#       offset: 10599887
#     cami (Tamanho: 32, Offset: 10599921)
#       Descrição: Box não documentado
#       size: 32
#       offset: 10599929
#   meta (Tamanho: 244, Offset: 10599953)
#     Descrição: Metadata Box - Estrutura para incluir metadados
#     hdlr (Tamanho: 33, Offset: 10599961)
#       Descrição: Handler Reference Box - Declara o tipo de mídia (áudio, vídeo, etc.)
#       flags: 0
#       pre_defined: 0
#       handler_type: mdta
#       name:
#     keys (Tamanho: 112, Offset: 10599994)
#       Descrição: Box não documentado
#       size: 112
#       offset: 10600002
#     ilst (Tamanho: 91, Offset: 10600106)
#       Descrição: Box não documentado
#       size: 91
#       offset: 10600114
#   trak (Tamanho: 2135, Offset: 10600197)
#     Descrição: Track Box - Contém uma faixa de áudio ou vídeo
#     tkhd (Tamanho: 92, Offset: 10600205)
#       Descrição: Track Header Box - Características gerais da faixa
#       version: 0
#       flags: 7
#       creation_time: 3838112710
#       modification_time: 3838112710
#       track_ID: 1
#       duration: 57059
#     mdia (Tamanho: 2035, Offset: 10600297)
#       Descrição: Media Box - Contém informações específicas da mídia da faixa
#       mdhd (Tamanho: 32, Offset: 10600305)
#         Descrição: Media Header Box - Informações gerais sobre os dados de mídia
#         version: 0
#         flags: 0
#         creation_time: 3838112710
#         modification_time: 3838112710
#         timescale: 90000
#         duration: 513531
#         language: ```
#       hdlr (Tamanho: 44, Offset: 10600337)
#         Descrição: Handler Reference Box - Declara o tipo de mídia (áudio, vídeo, etc.)
#         flags: 0
#         pre_defined: 0
#         handler_type: vide
#         name:
#       minf (Tamanho: 1951, Offset: 10600381)
#         Descrição: Media Information Box - Características da mídia para reprodução
#         vmhd (Tamanho: 20, Offset: 10600389)
#           Descrição: Box não documentado
#           size: 20
#           offset: 10600397
#         dinf (Tamanho: 36, Offset: 10600409)
#           Descrição: Data Information Box - Informações sobre onde os dados de mídia podem ser encontrados
#           dref (Tamanho: 28, Offset: 10600417)
#             Descrição: Box não documentado
#             size: 28
#             offset: 10600425
#         stbl (Tamanho: 1887, Offset: 10600445)
#           Descrição: Sample Table Box - Índices de tempo e dados para os quadros de mídia
#           stsd (Tamanho: 239, Offset: 10600453)
#             Descrição: Sample Description Box - Informações de codificação para cada formato de amostra
#             size: 239
#             offset: 10600461
#           stts (Tamanho: 792, Offset: 10600692)
#             Descrição: Decoding Time to Sample Box - Mapeamento de tempo para amostras
#             size: 792
#             offset: 10600700
#           stss (Tamanho: 40, Offset: 10601484)
#             Descrição: Sync Sample Box - Tabela de amostras-chave (keyframes)
#             size: 40
#             offset: 10601492
#           stsz (Tamanho: 704, Offset: 10601524)
#             Descrição: Sample Size Box - Tamanhos das amostras
#             size: 704
#             offset: 10601532
#           stsc (Tamanho: 40, Offset: 10602228)
#             Descrição: Sample to Chunk Box - Mapeamento de amostras para chunks
#             size: 40
#             offset: 10602236
#           co64 (Tamanho: 64, Offset: 10602268)
#             Descrição: Box não documentado
#             size: 64
#             offset: 10602276
#   trak (Tamanho: 1687, Offset: 10602332)
#     Descrição: Track Box - Contém uma faixa de áudio ou vídeo
#     tkhd (Tamanho: 92, Offset: 10602340)
#       Descrição: Track Header Box - Características gerais da faixa
#       version: 0
#       flags: 7
#       creation_time: 3838112710
#       modification_time: 3838112710
#       track_ID: 2
#       duration: 56796
#     edts (Tamanho: 48, Offset: 10602432)
#       Descrição: Edit Box - Define uma linha do tempo de edição para a faixa
#       elst (Tamanho: 40, Offset: 10602440)
#         Descrição: Box não documentado
#         size: 40
#         offset: 10602448
#     mdia (Tamanho: 1539, Offset: 10602480)
#       Descrição: Media Box - Contém informações específicas da mídia da faixa
#       mdhd (Tamanho: 32, Offset: 10602488)
#         Descrição: Media Header Box - Informações gerais sobre os dados de mídia
#         version: 0
#         flags: 0
#         creation_time: 3838112710
#         modification_time: 3838112710
#         timescale: 48000
#         duration: 272621
#         language: ```
#       hdlr (Tamanho: 44, Offset: 10602520)
#         Descrição: Handler Reference Box - Declara o tipo de mídia (áudio, vídeo, etc.)
#         flags: 0
#         pre_defined: 0
#         handler_type: soun
#         name:
#       minf (Tamanho: 1455, Offset: 10602564)
#         Descrição: Media Information Box - Características da mídia para reprodução
#         smhd (Tamanho: 16, Offset: 10602572)
#           Descrição: Box não documentado
#           size: 16
#           offset: 10602580
#         dinf (Tamanho: 36, Offset: 10602588)
#           Descrição: Data Information Box - Informações sobre onde os dados de mídia podem ser encontrados
#           dref (Tamanho: 28, Offset: 10602596)
#             Descrição: Box não documentado
#             size: 28
#             offset: 10602604
#         stbl (Tamanho: 1395, Offset: 10602624)
#           Descrição: Sample Table Box - Índices de tempo e dados para os quadros de mídia
#           stsd (Tamanho: 91, Offset: 10602632)
#             Descrição: Sample Description Box - Informações de codificação para cada formato de amostra
#             size: 91
#             offset: 10602640
#           stts (Tamanho: 96, Offset: 10602723)
#             Descrição: Decoding Time to Sample Box - Mapeamento de tempo para amostras
#             size: 96
#             offset: 10602731
#           stsz (Tamanho: 1084, Offset: 10602819)
#             Descrição: Sample Size Box - Tamanhos das amostras
#             size: 1084
#             offset: 10602827
#           stsc (Tamanho: 52, Offset: 10603903)
#             Descrição: Sample to Chunk Box - Mapeamento de amostras para chunks
#             size: 52
#             offset: 10603911
#           co64 (Tamanho: 64, Offset: 10603955)
#             Descrição: Box não documentado
#             size: 64
#             offset: 10603963

# %%
questioned_file = "20250815_112502.mp4"
standard_file = "vitor.mp4"

print(get_specific_comparison(all_comparisons, questioned_file, standard_file))
# Out:
# Similaridade entre '20250815_112502.mp4' e 'vitor.mp4': 0.96
# Diferenças:
# - Box 'elst': 1 vs 0
# - Relação 'trak->edts': 1 vs 0
# - Relação 'edts->elst': 1 vs 0
# - Box 'edts': 1 vs 0

# %%
similarity_matrix = create_and_plot_similarity_matrix(all_comparisons, questioned_structures, standard_structures, 'inferno')

#colormaps: jet, viridis, cividis, plasma inferno, magma, turbo, cubehelix, coolwarm
